# %% [markdown]
# <a href="https://colab.research.google.com/github/dvip1/Machine_learning/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #for reading the csv file 
import numpy as np #for creating arrays & doing some statistics 
import matplotlib.pyplot as plt #for plotting graphs 
from sklearn.linear_model import LogisticRegression #for classifying data in two types

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#declaring a variable that can read a csv file using pandas 
df = pd.read_csv('https://sololearn.com/uploads/files/titanic.csv')

# %%
df['male'] = df['Sex'] == 'male'#This acts a boolean function (True if male & False if female)
df.head #short glimpse of what's inside the document
# Out:
# <bound method NDFrame.head of      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare   male
# 0     7.2500   True
# 1    71.2833  False
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0           0       3    male  22.0                 1                 0
# 1           1       1  female  38.0                 1                 0
# 2           1       3  female  26.0                 0                 0
# 3           1       1  female  35.0                 1                 0
# 4           0       3    male  35.0                 0                 0
# ..        ...     ...     ...   ...               ...               ...
# 882         0       2    male  27.0                 0                 0
# 883         1       1  female  19.0                 0                 0
# 884         0       3  female   7.0                 1                 2
# 885         1       1    male  26.0                 0                 0
# 886         0       3    male  32.0                 0                 0
#
#         Fare   male
# 0     7.2500   True
# 1    71.2833  False
# ...

# %%
b= df[['Pclass', 'Fare', 'Age']].values #double brackets behaves like a numpy array
b.shape #It will give us the size of the document
# Out:
# (887, 3)

# %%
#It declares a boolean value, True if the age is smaller than 18
print(b[:,2] <18)
# Out:
# [False False False False False False False  True False  True  True False
#  False False  True False  True False False False False False  True False
#   True False False False False False False False False False False False
#  False False False  True False False  True False False False False  True
#  False  True False False False False False False False  True  True False
#  False False  True False  True False False  True False False  True False
#  False False False False False  True False False False False False  True
#  False  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True False False  True False False False False  True False
#  False False False False  True False False  True False False False False
#  False False False False False  True False False False False False False
#  False False  True False False False False False False False False  True
# ...

# %%
plt.xlabel('Age') #Labels x axis as Age
plt.ylabel('Fare') #Labels y axis as Fare 
plt.scatter(df['Age'], df['Fare']) # Plots a scatter graph of Age vs Fare

# %%
plt.xlabel('Age')
plt.ylabel('Fare')
plt.scatter(df['Age'], df['Fare'], c=df['Pclass']) #here Pclass is the third variable, it divides three classes in different shades
plt.plot([0,85],[85, 5]) 
plt.colorbar() #shows a colorbar
plt.show()

# %%
#(x1,x2)= (10,100) & (y1,y2)=(0, 3). The line travels from (0,10) to (100, 3)
plt.plot([10,100],[0, 3])

# %%
#Picking up a random variable and applying some math into it (numpy)
hel=np.array([10, 20, 40, 30, 40])
print(hel.mean())
print('This is median: ',np.median(hel))
# Out:
# 28.0
# This is median:  30.0

# %%
plt.xlabel('Age')
plt.ylabel('Fare')
plt.plot(df['Age'], df['Fare'], color='grey', label= 'Plot')

# %%
plt.scatter(df['Fare'], df['Age'], c=df['Survived'])
plt.colorbar()
plt.xlabel('Fare')
plt.ylabel('Age')
plt.plot([20,100], [0,80])

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  Siblings/Spouses  Parents/Children  \
# 0         0       3    male  22.0                 1                 0
# 1         1       1  female  38.0                 1                 0
# 2         1       3  female  26.0                 0                 0
# 3         1       1  female  35.0                 1                 0
# 4         0       3    male  35.0                 0                 0
#
#       Fare   male
# 0   7.2500   True
# 1  71.2833  False
# 2   7.9250  False
# 3  53.1000  False
# 4   8.0500   True

# %%
x1=df[['Pclass', 'Age', 'Siblings/Spouses', 'Parents/Children', 'male', 'Fare']].values # converting all the 'features' in database to numpy array
x2=df[['Fare', 'Age']]
y1=df['Survived'].values # 'target' coloumn

# %%
#All sklearn models are built as Python classes. We first instantiate the class.
model= LogisticRegression()

# %%
#Fitting the model means using the data to choose a line of best fit
model.fit(x1,y1)
# Out:
# LogisticRegression()

# %%
print(model.coef_, model.intercept_ )
# Out:
# [[-1.13645691 -0.04237384 -0.3874664  -0.09619819 -2.64409954  0.00297185]] [5.08857178]

# %%
print(model.predict([[3, True, 22.0, 1, 0, 7.25]]))  #he didn't survived according to this model
# Out:
# [0]

# %%
print(model.predict(x2[:5]))
print(y1[:5])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-440674e508ee> in <module>()
# ----> 1 print(model.predict(x2[:5]))
#       2 print(y1[:5])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# ...

# %%
model1= LogisticRegression()
model1.fit(X_train, Y)
